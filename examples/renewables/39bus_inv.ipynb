# %% [markdown]
# # IEEE 39-bus system with converters

# %%
from hermess.run import run

# %% [markdown]
# Import default configuration

# %%
from hermess.config import config

# %% [markdown]
# Now you can edit the default configuration and create your own. Optionally you can also change the disturbances and system parameters in the corresponding .txt files located in directory "testcases".

# %%
# Step 3: Prepare the new configuration
new_config = config.updated(testsystemfile="ieee39_conv")

# %%
run(new_config)
