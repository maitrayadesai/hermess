# %% [markdown]
# # Demo: the shipped IEEE 39-bus scenario

# %%
# Step 2: Import necessary functions
from hermess.run import run
from hermess.config import config

# Step 3: Prepare the new configuration
new_config = config.updated(ts=0.01, T_end=12.0)

# Step 4: Run the simulation with the updated config
run(new_config)
