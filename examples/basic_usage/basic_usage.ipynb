# %% [markdown]
# # Basic usage

# %%
from hermess.run import run

# %% [markdown]
# Import default configuration

# %%
from hermess.config import config

# %% [markdown]
# If you don't modify the configuration it will load the IEEE 39 bus test case with default simulation settings. You can run it:

# %%
run(config)
